# %% [markdown]
# # Classify Documents

# %%
# %load_ext autoreload
# %autoreload 2

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# ## Load Data
# The next cell will load embeddings generated in notebook [01-get-embeddings.ipynb](./01-get-embeddings.ipynb).

# %%
import pandas as pd

df_orig = pd.read_csv("../data/bbc-news-data-embedding.csv", delimiter='\t', index_col=False)

# %%
df = df_orig.copy()
df
# Out:
#       category filename                              title  \
# 0     business  001.txt  Ad sales boost Time Warner profit
# 1     business  002.txt   Dollar gains on Greenspan speech
# 2     business  003.txt  Yukos unit buyer faces loan claim
# 3     business  004.txt  High fuel prices hit BA's profits
# 4     business  005.txt  Pernod takeover talk lifts Domecq
# ...        ...      ...                                ...
# 2220      tech  397.txt   BT program to beat dialler scams
# 2221      tech  398.txt    Spam e-mails tempt net shoppers
# 2222      tech  399.txt            Be careful how you code
# 2223      tech  400.txt    US cyber security chief resigns
# 2224      tech  401.txt   Losing yourself in online gaming
#
#                                                 content  \
# 0      Quarterly profits at US media giant TimeWarne...
# 1      The dollar has hit its highest level against ...
# 2      The owners of embattled Russian oil giant Yuk...
# 3      British Airways has blamed high fuel prices f...
# 4      Shares in UK drinks and food firm Allied Dome...
# ...                                                 ...
# 2220   BT is introducing two initiatives to help bea...
# 2221   Computer users across the world continue to i...
# 2222   A new European directive could put software w...
# 2223   The man making sure US computer networks are ...
# 2224   Online role playing games are time-consuming,...
#
#                                               embedding
# 0     [-0.0012276918860152364, 0.00733763724565506, ...
# 1     [0.0009311728645116091, 0.014099937863647938, ...
# 2     [-0.010487922467291355, 0.009665092453360558, ...
# 3     [0.0111119095236063, 0.004624682944267988, -0....
# 4     [-0.0021637482568621635, 0.005410161800682545,...
# ...                                                 ...
# 2220  [0.007671569474041462, 0.00624304823577404, -0...
# 2221  [0.0026338498573750257, 0.015989987179636955, ...
# 2222  [0.007126151118427515, 0.008495588786900043, -...
# 2223  [0.002447678940370679, 0.006076449993997812, -...
# 2224                                                NaN
#
# [2225 rows x 5 columns]

# %%
# drop rows with NaN
df.dropna(inplace=True)
len(df)
# Out:
# 2217

# %% [markdown]
# ## Classify documents with their embeddings
# ref: https://github.com/openai/openai-cookbook/blob/main/examples/Classification_using_embeddings.ipynb

# %%
import pandas as pd
import numpy as np

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# convert string to array
df["embedding"] = df['embedding'].apply(eval).apply(np.array)  

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2217 entries, 0 to 2223
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   category   2217 non-null   object
#  1   filename   2217 non-null   object
#  2   title      2217 non-null   object
#  3   content    2217 non-null   object
#  4   embedding  2217 non-null   object
# dtypes: object(5)
# memory usage: 103.9+ KB

# %%
X = df['embedding']
y = df['category']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42, shuffle=True, stratify=y) 

# reshape X into 2D array
X_train = np.vstack(X_train)
X_test = np.vstack(X_test)

# %% [markdown]
# ## Fit a model with `XGBoost`

# %%
from xgboost import XGBClassifier
import pickle

TRAIN = False
LOAD = True

# filename for trained model
fname = '../output/models/xgb.pkl'

if TRAIN: 
    # create model instance
    xgb = XGBClassifier(n_estimators=100, max_depth=5, learning_rate=1, objective='multi:softprob')
    # fit model
    xgb.fit(X_train, y_train)

    # save the model to disk
    with open(fname, "wb") as f:
        pickle.dump(xgb, f)
 
# load the model from disk
if LOAD:
    with open(fname, "rb") as f:
        xgb = pickle.load(f)

# predict
preds = xgb.predict(X_test)
probas = xgb.predict_proba(X_test)

# report
report = classification_report(y_test, preds)
print(report)
# Out:
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [13:27:07] WARNING: /mnt/xgboost/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=1, max_delta_step=0, max_depth=5,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=100, n_jobs=2, num_parallel_tree=1,
#               objective='multi:softprob', random_state=0, reg_alpha=0,
#               reg_lambda=1, scale_pos_weight=None, subsample=1,
#               tree_method='exact', use_label_encoder=True,
#               validate_parameters=1, verbosity=None)
#                precision    recall  f1-score   support
#
#      business       0.92      0.92      0.92       168
# entertainment       0.94      0.93      0.93       127
#      politics       0.90      0.90      0.90       137
#         sport       0.98      0.98      0.98       168
#          tech       0.92      0.93      0.93       132
#
#      accuracy                           0.93       732
#     macro avg       0.93      0.93      0.93       732
#  weighted avg       0.93      0.93      0.93       732

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay

# confusion matrix
cm = confusion_matrix(y_test, preds)
cm_display = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=xgb.classes_).plot()

# %% [markdown]
# ## Save predictions

# %%
y_test_pred = pd.DataFrame()
y_test_pred['category'] = y_test
y_test_pred['prediction'] = preds
y_test_pred
# Out:
#            category     prediction
# 252        business       business
# 1414          sport          sport
# 567   entertainment  entertainment
# 1460          sport          sport
# 775   entertainment           tech
# ...             ...            ...
# 421        business       business
# 1987           tech           tech
# 273        business       business
# 1047       politics       politics
# 2135           tech           tech
#
# [732 rows x 2 columns]

# %%
df_test_result = pd.concat([df, y_test_pred.drop(columns='category')], axis=1, join="inner")
df_test_result.shape
df_test_result
# Out:
# (732, 6)
#       category filename                               title  \
# 1     business  002.txt    Dollar gains on Greenspan speech
# 4     business  005.txt   Pernod takeover talk lifts Domecq
# 8     business  009.txt   Ethiopia's crop production up 24%
# 13    business  014.txt    Telegraph newspapers axe 90 jobs
# 14    business  015.txt    Air passengers win new EU rights
# ...        ...      ...                                 ...
# 2209      tech  386.txt    Video phones act as dating tools
# 2212      tech  389.txt  Mobile multimedia slow to catch on
# 2213      tech  390.txt    Anti-spam laws bite spammer hard
# 2216      tech  393.txt    Savvy searchers fail to spot ads
# 2222      tech  399.txt             Be careful how you code
#
#                                                 content  \
# 1      The dollar has hit its highest level against ...
# 4      Shares in UK drinks and food firm Allied Dome...
# 8      Ethiopia produced 14.27 million tonnes of cro...
# 13     The Daily and Sunday Telegraph newspapers are...
# 14     Air passengers who are unable to board their ...
# ...                                                 ...
# 2209   Technologies, from e-mail, to net chatrooms, ...
# 2212   There is no doubt that mobile phones sporting...
# 2213   The net's self-declared spam king is seeking ...
# 2216   Internet search engine users are an odd mix o...
# 2222   A new European directive could put software w...
#
#                                               embedding prediction
# 1     [0.0009311728645116091, 0.014099937863647938, ...   business
# 4     [-0.0021637482568621635, 0.005410161800682545,...   business
# 8     [0.008323440328240395, 0.014594526030123234, -...   business
# 13    [-0.001993480371311307, 0.0038063114043325186,...   business
# 14    [0.01202255580574274, 0.0024986255448311567, -...   business
# ...                                                 ...        ...
# 2209  [-0.0021125166676938534, -0.003049303079023957...       tech
# 2212  [0.007488378323614597, 0.007830777205526829, -...       tech
# 2213  [-0.002103055827319622, 0.00393986189737916, -...       tech
# 2216  [0.00633224518969655, 0.007613884285092354, -0...       tech
# 2222  [0.007126151118427515, 0.008495588786900043, -...       tech
#
# [732 rows x 6 columns]

# %% [markdown]
# ## Save Results

# %%
# Save results
fname = '../output/predictions.csv'
df_test_result.to_csv(fname, sep='\t')

# %% [markdown]
# ## Wrong Predictions

# %%
df_wrong_predictions = df_test_result[df_test_result['category'] != df_test_result['prediction']]
df_wrong_predictions
# Out:
#            category filename                                 title  \
# 105        business  106.txt     Golden rule 'intact' says ex-aide
# 212        business  213.txt     US bank boss hails 'genius' Smith
# 226        business  227.txt       Call to save manufacturing jobs
# 235        business  236.txt       Card fraudsters 'targeting web'
# 240        business  241.txt      G7 backs Africa debt relief plan
# 241        business  242.txt       Q&A: Malcolm Glazer and Man Utd
# 254        business  255.txt     Call to overhaul UK state pension
# 292        business  293.txt     Glazer makes new Man Utd approach
# 387        business  388.txt     Venezuela identifies 'idle' farms
# 412        business  413.txt      EC calls truce in deficit battle
# 451        business  452.txt     McDonald's boss Bell dies aged 44
# 456        business  457.txt           Germany calls for EU reform
# 459        business  460.txt      Jobs go at Oracle after takeover
# 518   entertainment  009.txt      Da Vinci Code is 'lousy history'
# 657   entertainment  148.txt     Pupils to get anti-piracy lessons
# 682   entertainment  173.txt       UK TV channel rapped for CSI ad
# 692   entertainment  183.txt     Star Trek fans fight to save show
# 711   entertainment  202.txt      BBC 'should allow more scrutiny'
# 775   entertainment  266.txt     Help for indies in download sales
# 822   entertainment  313.txt       BBC to pour £9m into new comedy
# 851   entertainment  342.txt      US composer recreates Bach score
# 893   entertainment  384.txt      Robots march to US cinema summit
# 899        politics  004.txt             Labour chooses Manchester
# 901        politics  006.txt       'Errors' doomed first Dome sale
# 918        politics  023.txt      E-University 'disgraceful waste'
# 971        politics  076.txt       Report attacks defence spending
# 985        politics  090.txt     MSPs hear renewed climate warning
# 1004       politics  109.txt       UK firms 'embracing e-commerce'
# 1008       politics  113.txt      MP's shock at long lost daughter
# 1034       politics  139.txt           Straw praises Kashmir moves
# 1035       politics  140.txt          UK helps raped Rwandan women
# 1073       politics  178.txt       Hatfield executives go on trial
# 1089       politics  194.txt      Cherie accused of attacking Bush
# 1225       politics  330.txt     Manchester wins Labour conference
# 1288       politics  393.txt        Parliament's record of scandal
# 1308       politics  413.txt      Sainsbury's Labour election gift
# 1316          sport  004.txt     IAAF launches fight against drugs
# 1339          sport  027.txt      Holmes feted with further honour
# 1443          sport  131.txt     Newry to fight cup exit in courts
# 1675          sport  363.txt       Calder fears for Scottish rugby
# 1824           tech  001.txt     Ink helps drive democracy in Asia
# 1848           tech  025.txt     Sony PSP console hits US in March
# 1851           tech  028.txt         Piero gives rugby perspective
# 1858           tech  035.txt       Iran jails blogger for 14 years
# 1946           tech  123.txt        Attack prompts Bush site block
# 2011           tech  188.txt      Call for action on internet scam
# 2046           tech  223.txt  Satellite mapping aids Darfur relief
# 2054           tech  231.txt       Parents face video game lessons
# 2140           tech  317.txt     Sony PSP console hits US in March
#
#                                                 content  \
# 105    Chancellor Gordon Brown will meet his golden ...
# 212    US Federal Reserve chairman Alan Greenspan ha...
# 226    The Trades Union Congress (TUC) is calling on...
# 235    New safeguards on credit and debit card payme...
# 240    G7 finance ministers have backed plans to wri...
# 241    The battle for control of Manchester United h...
# 254    The UK pension system has been branded inadeq...
# 292    Malcolm Glazer has made a fresh approach to b...
# 387    Venezuelan authorities have identified more t...
# 412    The European Commission (EC) has called a tru...
# 451    Charlie Bell, the straight-talking former hea...
# 456    German Chancellor Gerhard Schroeder has calle...
# 459    Oracle has announced it is cutting about 5,00...
# 518    The plot of an international bestseller that ...
# 657    Lessons on music piracy and copyright issues ...
# 682    TV channel Five has been criticised for sendi...
# 692    Star Trek fans have taken out a full-page ad ...
# 711    MPs have urged the BBC to give watchdogs more...
# 775    A campaign has been launched to help independ...
# 822    The BBC is to invest £9m in developing new co...
# 851    A US musicologist has recreated a lost musica...
# 893    Animated movie Robots has opened at the top o...
# 899    The Labour Party will hold its 2006 autumn co...
# 901    The initial attempt to sell the Millennium Do...
# 918    A failed government scheme to offer UK univer...
# 971    The Ministry of Defence has been criticised o...
# 985    Climate change could be completely out of con...
# 1004   UK firms are embracing internet trading oppor...
# 1008   Labour MP Stephen Pound has told of his shock...
# 1034   The UK has welcomed the decision by India and...
# 1035   Britain is to give a £4m grant to help women ...
# 1073   Engineering firm Balfour Beatty and five rail...
# 1089   Cherie Blair has been accused of criticising ...
# 1225   The Labour Party will hold its 2006 autumn co...
# 1288   In a locked room at the heart of Parliament t...
# 1308   Science Minister Lord Sainsbury has made a £2...
# 1316   The IAAF - athletics' world governing body - ...
# 1339   Double Olympic champion Kelly Holmes has been...
# 1443   Newry City are expected to discuss legal aven...
# 1675   Former Scotland international Finlay Calder f...
# 1824   The Kyrgyz Republic, a small, mountainous sta...
# 1848   US gamers will be able to buy Sony's PlayStat...
# 1851   BBC Sport unveils its new analysis tool Piero...
# 1858   An Iranian weblogger has been jailed for 14 y...
# 1946   The official re-election site of President Ge...
# 2011   Phone companies are not doing enough to warn ...
# 2046   Aid workers trying to house, feed and clothe ...
# 2054   Ways of ensuring that parents know which vide...
# 2140   US gamers will be able to buy Sony's PlayStat...
#
#                                               embedding     prediction
# 105   [0.006964212749153376, 0.0015263919485732913, ...       politics
# 212   [0.0021459858398884535, 0.0036910325288772583,...  entertainment
# 226   [0.0012122669722884893, 0.0076951221562922, -0...       politics
