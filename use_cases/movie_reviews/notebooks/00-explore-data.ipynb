# %% [markdown]
# # Explore Data

# %%
# %load_ext autoreload
# %autoreload 2

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# ## Load Data

# %%
import pandas as pd

df_orig = pd.read_csv("../data/rottentomatoes-400k.csv", index_col=[0])
df_orig.drop(columns='Reviewer', inplace=True)

# %%
df = df_orig.copy()
df
# Out:
#                                     Movie                    Publish  \
# 0       HOTEL TRANSYLVANIA: TRANSFORMANIA                    City AM
# 1       HOTEL TRANSYLVANIA: TRANSFORMANIA  AniMat's Review (YouTube)
# 2       HOTEL TRANSYLVANIA: TRANSFORMANIA                    Newsday
# 3       HOTEL TRANSYLVANIA: TRANSFORMANIA          jackiekcooper.com
# 4       HOTEL TRANSYLVANIA: TRANSFORMANIA               The Playlist
# ...                                   ...                        ...
# 421488          HITLER: THE LAST TEN DAYS          Chicago Sun-Times
# 421489          HITLER: THE LAST TEN DAYS                   TV Guide
# 421490                   THE ONE AND ONLY            Chicago Tribune
# 421491                   THE ONE AND ONLY     San Francisco Examiner
# 421492                   THE ONE AND ONLY          Chicago Sun-Times
#
#                                                    Review        Date  Score
# 0       I guess its always been hard for me to see the...  03/03/2022   40.0
# 1       Hotel Transylvania: Transformania is a present...  15/02/2022   30.0
# 2       The conceit still works well enough to mostly ...  29/01/2022   75.0
# 3       No Adam Sandler this time out, but the animate...  28/01/2022   60.0
# 4       It's not likely we'll see another one of these...  28/01/2022   74.0
# ...                                                   ...         ...    ...
# 421488  There's no tragedy in this movie, no sense of ...  13/06/2020   25.0
# 421489  Yet another failed attempt to make the Fuhrer ...  23/02/2012   40.0
# 421490  "The One and Only" is really two stories at od...  31/08/2021   50.0
# 421491  [A] silly, old-fashioned comedy directed with ...  31/08/2021   75.0
# 421492  It's a pleasant movie, it has some genuinely f...  15/06/2018   62.5
#
# [417058 rows x 5 columns]

# %%
# convert the 'Date' column to datetime format
df['Date']= pd.to_datetime(df['Date'])

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 417058 entries, 0 to 421492
# Data columns (total 5 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   Movie    417058 non-null  object
#  1   Publish  417058 non-null  object
#  2   Review   417058 non-null  object
#  3   Date     417058 non-null  datetime64[ns]
#  4   Score    417058 non-null  float64
# dtypes: datetime64[ns](1), float64(1), object(3)
# memory usage: 19.1+ MB

# %%
df.describe(include='all', datetime_is_numeric=True)
# Out:
#          Movie         Publish                                Review  \
# count   417058          417058                                417058
# unique    9366            1615                                416395
# top      JOKER  Slant Magazine  full review at Movies for the Masses
# freq       380            4977                                   159
# mean       NaN             NaN                                   NaN
# min        NaN             NaN                                   NaN
# 25%        NaN             NaN                                   NaN
# 50%        NaN             NaN                                   NaN
# 75%        NaN             NaN                                   NaN
# max        NaN             NaN                                   NaN
# std        NaN             NaN                                   NaN
#
#                                  Date          Score
# count                          417058  417058.000000
# unique                            NaN            NaN
# top                               NaN            NaN
# freq                              NaN            NaN
# mean    2015-03-12 19:04:44.869888768      65.330320
# min               1800-01-01 00:00:00       0.000000
# 25%               2012-02-03 00:00:00      50.000000
# 50%               2015-05-28 00:00:00      69.000000
# 75%               2018-08-14 00:00:00      80.000000
# max               2022-12-03 00:00:00     100.000000
# std                               NaN      19.691417

# %% [markdown]
# ## Movies with Most Reviews

# %%
#create bar plot to visualize frequency of each team
df['Movie'].value_counts()[0:100].plot(kind='bar', 
                                      xlabel='Category', 
                                      ylabel='Articles Count', 
                                      rot=90, 
                                      title='Number of articles per category',
                                      figsize=(15,5))
# Out:
# <Axes: title={'center': 'Number of articles per category'}, xlabel='Category', ylabel='Articles Count'>

# %% [markdown]
# ## About Reviews
# Some `Review` contain not meaningful text, e.g. 'click for full review', etc.

# %%
df[df['Review']=='click for full review']
# Out:
#                             Movie                Publish  \
# 54033            THE EDGE OF LOVE  Movies for the Masses
# 369146       LET THE RIGHT ONE IN  Movies for the Masses
# 375887            BROKEN EMBRACES  Movies for the Masses
# 377804                 ANTICHRIST  Movies for the Masses
# 381981               HALLOWEEN II  Movies for the Masses
# 384154                 LION'S DEN  Movies for the Masses
# 384495                    G-FORCE  Movies for the Masses
# 385951               FUNNY PEOPLE  Movies for the Masses
# 395173  LET'S TALK ABOUT THE RAIN  Movies for the Masses
# 395190                    KNOWING  Movies for the Masses
# 413867                  RED CLIFF  Movies for the Masses
# 414997                 88 MINUTES  Movies for the Masses
# 419421                 SUMMER '04  Movies for the Masses
#
#                        Review       Date  Score
# 54033   click for full review 2009-05-14   50.0
# 369146  click for full review 2009-05-14  100.0
# 375887  click for full review 2009-10-13   40.0
# 377804  click for full review 2009-10-13   20.0
# 381981  click for full review 2009-10-13   80.0
# 384154  click for full review 2009-05-14   50.0
# 384495  click for full review 2009-10-13   20.0
# 385951  click for full review 2009-10-13   60.0
# 395173  click for full review 2009-05-14   60.0
# 395190  click for full review 2009-05-14   40.0
# 413867  click for full review 2009-05-14   40.0
# 414997  click for full review 2007-07-21   30.0
# 419421  click for full review 2007-07-21   50.0

# %%
df['Review'].value_counts()[0:10]
# Out:
# full review at Movies for the Masses    159
# click to read full review                14
# click for full review                    13
# podcast review                           12
# Click for full review                     9
# One of the ten best films of 2012.        9
# click to read the full review             9
# What a disappointment.                    7
# A missed opportunity.                     6
# A masterpiece.                            6
# Name: Review, dtype: int64

# %% [markdown]
# ## Text Length

# %%
df["Word_Count"] = df["Review"].apply(lambda n: len(n.split()))
df
# Out:
#                                     Movie                    Publish  \
# 0       HOTEL TRANSYLVANIA: TRANSFORMANIA                    City AM
# 1       HOTEL TRANSYLVANIA: TRANSFORMANIA  AniMat's Review (YouTube)
# 2       HOTEL TRANSYLVANIA: TRANSFORMANIA                    Newsday
# 3       HOTEL TRANSYLVANIA: TRANSFORMANIA          jackiekcooper.com
# 4       HOTEL TRANSYLVANIA: TRANSFORMANIA               The Playlist
# ...                                   ...                        ...
# 421488          HITLER: THE LAST TEN DAYS          Chicago Sun-Times
# 421489          HITLER: THE LAST TEN DAYS                   TV Guide
# 421490                   THE ONE AND ONLY            Chicago Tribune
# 421491                   THE ONE AND ONLY     San Francisco Examiner
# 421492                   THE ONE AND ONLY          Chicago Sun-Times
#
#                                                    Review       Date  Score  \
# 0       I guess its always been hard for me to see the... 2022-03-03   40.0
# 1       Hotel Transylvania: Transformania is a present... 2022-02-15   30.0
# 2       The conceit still works well enough to mostly ... 2022-01-29   75.0
# 3       No Adam Sandler this time out, but the animate... 2022-01-28   60.0
# 4       It's not likely we'll see another one of these... 2022-01-28   74.0
# ...                                                   ...        ...    ...
# 421488  There's no tragedy in this movie, no sense of ... 2020-06-13   25.0
# 421489  Yet another failed attempt to make the Fuhrer ... 2012-02-23   40.0
# 421490  "The One and Only" is really two stories at od... 2021-08-31   50.0
# 421491  [A] silly, old-fashioned comedy directed with ... 2021-08-31   75.0
# 421492  It's a pleasant movie, it has some genuinely f... 2018-06-15   62.5
#
#         Word_Count
# 0               42
# 1               27
# 2               15
# 3               13
# 4               23
# ...            ...
# 421488          17
# 421489          13
# 421490          13
# 421491          11
# 421492          32
#
# [417058 rows x 6 columns]

# %% [markdown]
# ### plot `Word_Count` per `Review`

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# plot word counts for reviews of first 100 movies
df_plot = df[df['Movie'].isin(df['Movie'].value_counts()[0:100].index.to_list())]
_ = sns.catplot(data=df_plot, x="Movie", y="Word_Count", kind="box", height=4, aspect=4)
_ = plt.xticks(rotation=90)

# %% [markdown]
# ## Subset of data

# %%
movie_list = df['Movie'].value_counts()[0:20].index.to_list()

df_sub = df[df['Movie'].isin(movie_list)]
df_sub
# Out:
#                                Movie              Publish  \
# 8457         SOLO: A STAR WARS STORY          Stuff.co.nz
# 9207                   BLACK PANTHER  Gone With The Twins
# 11458                        DUNKIRK       Screen Zealots
# 15446                     KNIVES OUT         Student Edge
# 18961                     KNIVES OUT    Deep Focus Review
# ...                              ...                  ...
# 137428  ROGUE ONE: A STAR WARS STORY         Movie Nation
# 137429  ROGUE ONE: A STAR WARS STORY              Newsday
# 137430  ROGUE ONE: A STAR WARS STORY                Metro
# 137431  ROGUE ONE: A STAR WARS STORY          Den of Geek
# 137432  ROGUE ONE: A STAR WARS STORY  We Got This Covered
#
#                                                    Review       Date  Score  \
# 8457                 The formula is strong with this one. 2018-05-24   70.0
# 9207     Just about the same as every other Marvel title. 2020-05-12   50.0
# 11458         This is one heck of a stunning war picture. 2018-12-20   80.0
# 15446   Don't fear: No spoilers here. All you need to ... 2019-11-26   80.0
# 18961   Sharp and funny, Knives Out exceeds expectatio... 2022-02-23  100.0
# ...                                                   ...        ...    ...
# 137428  This is more like it...the 'Star Wars' movie J... 2016-12-13   75.0
# 137429  This "Star Wars" spinoff doesn't spin very far... 2016-12-13   75.0
# 137430  Boasts thin characters played by great actors ... 2016-12-13   40.0
# 137431  Rogue One builds to one of the best third acts... 2016-12-13   80.0
# 137432  Rogue One makes up for a shaky first act by pu... 2016-12-13   70.0
#
#         Word_Count
# 8457             7
# 9207             9
# 11458            9
# 15446           17
# 18961           29
# ...            ...
# 137428          13
# 137429          19
# 137430          37
# 137431          14
# 137432          26
#
# [6640 rows x 6 columns]

# %% [markdown]
# ## Save data

# %%
df_sub.to_csv("../data/rottentomatoes-20movies-wordcount.csv", sep='\t', index=False)

# %%
# load data
pd.read_csv("../data/rottentomatoes-20movies-wordcount.csv", sep='\t')
# Out:
#                              Movie              Publish  \
# 0          SOLO: A STAR WARS STORY          Stuff.co.nz
# 1                    BLACK PANTHER  Gone With The Twins
# 2                          DUNKIRK       Screen Zealots
# 3                       KNIVES OUT         Student Edge
# 4                       KNIVES OUT    Deep Focus Review
# ...                            ...                  ...
# 6635  ROGUE ONE: A STAR WARS STORY         Movie Nation
# 6636  ROGUE ONE: A STAR WARS STORY              Newsday
# 6637  ROGUE ONE: A STAR WARS STORY                Metro
# 6638  ROGUE ONE: A STAR WARS STORY          Den of Geek
# 6639  ROGUE ONE: A STAR WARS STORY  We Got This Covered
#
#                                                  Review        Date  Score  \
# 0                  The formula is strong with this one.  2018-05-24   70.0
# 1      Just about the same as every other Marvel title.  2020-05-12   50.0
# 2           This is one heck of a stunning war picture.  2018-12-20   80.0
# 3     Don't fear: No spoilers here. All you need to ...  2019-11-26   80.0
# 4     Sharp and funny, Knives Out exceeds expectatio...  2022-02-23  100.0
# ...                                                 ...         ...    ...
# 6635  This is more like it...the 'Star Wars' movie J...  2016-12-13   75.0
# 6636  This "Star Wars" spinoff doesn't spin very far...  2016-12-13   75.0
# 6637  Boasts thin characters played by great actors ...  2016-12-13   40.0
# 6638  Rogue One builds to one of the best third acts...  2016-12-13   80.0
# 6639  Rogue One makes up for a shaky first act by pu...  2016-12-13   70.0
#
#       Word_Count
# 0              7
# 1              9
# 2              9
# 3             17
# 4             29
# ...          ...
# 6635          13
# 6636          19
# 6637          37
# 6638          14
# 6639          26
#
# [6640 rows x 6 columns]
